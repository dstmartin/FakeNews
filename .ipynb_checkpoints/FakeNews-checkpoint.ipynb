# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import the dataset
data = pd.read_csv('data/train.csv')
data.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
data.shape
# Out:
# (20800, 5)

# %%
# Drop the columns that are not needed
data = data.drop(['title'], axis=1)

# %%
# Check for missing values
data.isnull().sum()
# Out:
# id           0
# author    1957
# text        39
# label        0
# dtype: int64

# %%
# Replace null value in author with "Unknown"
data['author'] = data['author'].fillna('Unknown')

# %%
# Drop the rows with missing values
data = data.dropna()

# %%
# Shuffle the dataset and drop the index
data = data.sample(frac=1)
data.reset_index(inplace=True)
data.drop(['index'], axis=1, inplace=True)

# %%
data
# Out:
#           id           author  \
# 0       1718  Kaitlyn Stegall
# 1      12554      Ben Hubbard
# 2      18377      Michael Luo
# 3       6432          recrisp
# 4      17630    Patrick Healy
# ...      ...              ...
# 20756   7857       Neil Munro
# 20757   8492          The Doc
# 20758   9136          Unknown
# 20759   3287          Unknown
# 20760  20770       Iron Sheik
#
#                                                     text  label
# 0      October 26, 2016 Denuclearizing N. Korea a ‘lo...      1
# 1      JIDDA, Saudi Arabia  —   For most of his adult...      0
# 2      Dear Madam: Maybe I should have let it go. Tur...      0
# 3      link Years ago I came here for the UFOs and af...      1
# 4      CLEVELAND  —   Until Monday night, Donald J. T...      0
# ...                                                  ...    ...
# 20756  Major   cities need to import yet more immigra...      0
# 20757  By Stewart Dougherty: \n“ There never was a de...      1
# ...

# %%
ax = sns.countplot(data=data, x='label', order=data['label'].value_counts().index, palette='tab10', hue='label', legend=False)

# Change x-axis labels to 'Fake' and 'Real'
ax.set_xticklabels(['Real', 'Fake'])

# Annotate each bar with the count
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
# Out:
# /var/folders/09/8wlbz8dd26dfzjrwrpsmm7sw0000gp/T/ipykernel_49632/3655328954.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Real', 'Fake'])

# %% [markdown]
# # Create a wordcloud for the text

# %%
# Setup modules to create the wordcloud
from tqdm import tqdm
import re
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/dstmartin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/dstmartin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Preprocess the data given as input
def preprocess_data(text_data):
    corpus = []
    for sentence in tqdm(text_data):
        sentence = re.sub('[^a-zA-Z]', ' ', sentence)
        corpus.append(' '.join(token.lower() for token in str(sentence).split() if token not in stopwords.words('english')))
    return corpus

# %%
preprocessed_reviews = preprocess_data(data['text'].values)
data['text'] = preprocessed_reviews
# Out:
# 100%|██████████| 20761/20761 [32:31<00:00, 10.64it/s]

# %% [markdown]
# # Visualize the wordcloud for fake and real news

# %%
# Real news
consolidated = ' '.join(word for word in data['text'][data['label'] == 1].astype(str))
wordcloud = WordCloud(width=1600, height=800, random_state=21, max_font_size=110, collocations=False)
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud.generate(consolidated), interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Fake news

consolidated = ' '.join(word for word in data['text'][data['label'] == 0].astype(str))
wordcloud = WordCloud(width=1600, height=800, random_state=21, max_font_size=110, collocations=False)
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud.generate(consolidated), interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Chart the top 35 words used in the dataset

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
#plot the bargraph of the top 35 words and omit "said"

def plot_top_words(corpus, number=None):
    cv = CountVectorizer(stop_words='english')
    words = cv.fit_transform(corpus)
    sum_words = words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in cv.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    frequency = pd.DataFrame(words_freq, columns=['word', 'freq'])

    # Exclude the word 'said'
    frequency = frequency[~frequency['word'].isin(['said', 'mr'])]
       
    # Plot the barplot
    plt.figure(figsize=(15, 10))
    sns.barplot(x='word', y='freq', data=frequency.head(number), palette='tab10', hue='word', legend=False)
    plt.title('Top 35 words in the dataset')
    plt.xticks(rotation='vertical')
    plt.show()

# %%
plot_top_words(data['text'], 35)
